# %% [markdown]
# ## Lesson-01 Assignment

# %% [markdown]
# #### 今天是2020年08月16日，今天世界上又多了一名AI工程师 :)

# %% [markdown]
# ## 本次作业的内容

# %% [markdown]
# #### 1. 复现课堂代码
#
# 在本部分，你需要参照我们给大家的GitHub地址里边的课堂代码，结合课堂内容，复现内容。

# %% [markdown]
# #### 2. 完成以下问答和编程练习

# %% [markdown]
# >

# %% [markdown]
# ## 基础理论部分

# %% [markdown]
# #### 0. Can you come up out 3 sceneraies which use AI methods?

# %% [markdown]
# - 计算机视觉领域相关应用：人脸识别、目标检测与跟踪、自动驾驶等；
# - 自然语言处理领域相关应用：智能客服(阿里小蜜)、聊天机器人(微软小冰)；
# - 推荐场景：抖音的推荐系统、电商推荐系统等

# %% [markdown]
# #### 1. How do we use Github; Why do we use Jupyter and Pycharm;

# %% [markdown]
# 我认为Github主要有一下几个使用场景：<br>
# - 当我们想要解决某个问题的时候，就会去Github上进行搜索看看有没有已有的开源的解决方案或者工具；
# - 阅读或参与开源项目来进行学习，我们可以寻找那些star和fork数比较多的项目去学习，这种开源项目质量比较高；
# - 团队协作开发，团队项目开发一般都是在Github上创建一个repo进行维护，能够清楚记录项目修改记录，方便更新与合并代码。
#
# Jupyter and Pycharm：<br>
# - Jupyter适合做一下代码中间结果的可视化展示或者用于教学demo演示，方便代码和笔记集成；
# - Pycharm适合做中大型项目，有强大的debug功能、代码跳转、变量提示等功能。

# %% [markdown]
# #### 2. What's the Probability Model?

# %% [markdown]
# 概率模型（Statistical Model，也称为Probabilistic Model）是用来描述不同随机变量之间关系的数学模型，通常情况下刻画了一个或多个随机变量之间的相互非确定性的概率关系。从数学上讲，该模型通常被表达为 ，其中 Y 是观测集合用来描述可能的观测结果， P 是 Y 对应的概率分布函数集合。若使用概率模型，一般而言需假设存在一个确定的分布P 生成观测数据 Y 。因此通常使用统计推断的办法确定集合 P 中谁是数据产生的原因。

# %% [markdown]
# #### 3. Can you came up with some sceneraies at which we could use Probability Model?

# %% [markdown]
# 大多数统计检验都可以理解成一种概率模型；机器学习说到底，就是要根据已有的数据集建立（或者说学习到）一个概率模型（Probabilistic Model）。该模型以新的数据做输入时，其输出符合已有的数据集的分布；nlp中的语言模型也应用了条件概率模型；在深度学习中的参数初始化也经常应用概率模型，比如以某种概率分布随机初始化参数能够加快模型收敛。

# %% [markdown]
# #### 4. Why do we use probability and what's the difficult points for programming based on parsing and pattern match?

# %% [markdown]
# 使用解析和模式匹配的方式编程的难点在于输入数据变化后，解析和匹配模式需要改变，即代码需要很大程度上重构。而使用概率统计的方式可以避免程序需要频繁重写的问题。

# %% [markdown]
# #### 5. What's the Language Model;

# %% [markdown]
# 语言模型是用来计算一段文本概率的模型，如果计算某段文本的概率大于另一端文本的概率，则该段文本更符合常理。

# %% [markdown]
# #### 6. Can you came up with some sceneraies at which we could use Language Model?

# %% [markdown]
# 语言模型会应用在文本分类、语音识别和机器翻译等领域，可以提升性能。例如，在语音识别中，给定一段“厨房里食用油用完了”的语音，有可能会输出“厨房里食油用完了”和“厨房里石油用完了”这两个读音完全一样的文本序列。如果语言模型判断出前者的概率大于后者的概率，我们就可以根据相同读音的语音输出“厨房里食油用完了”的文本序列。在机器翻译中，如果对英文“you go first”逐词翻译成中文的话，可能得到“你先走”“你走先”等排列方式的文本序列。如果语言模型判断出“你先走”的概率大于其他排列方式的文本序列的概率，我们就可以把“you go first”翻译成“你先走”。

# %% [markdown]
# #### 7. What's the 1-gram language model;

# %% [markdown]
# 1-gram模型是基于独立性假设，各个词之间相互独立，各个词独立出现概率的累乘。比如$S = “你先走”$这句话，1-gram的模型表示为：$P(S) = P("你")*P("先")*P("走")$

# %% [markdown]
# #### 8. What's the disadvantages and advantages of 1-gram language model;

# %% [markdown]
# 1-gram语言模型存储和计算量小，但是准确率较低，没有考虑相邻词的信息，例如，在1-gram中，由3个词组成的句子"你先走"和“你走先”的概率是一样的，即$P("你先走") = P("你")*P("先")*P("走") = P("你")*P("走")*P("先") = P("你走先")$，但是实际考虑“你先走”更符合我们的语法习惯，概率应该要大一些。

# %% [markdown]
# #### 9. What't the 2-gram models;

# %% [markdown]
# 2-gram模型会考虑每个词在前一个词出现情况下的条件概率，即考虑相邻一个词的依赖关系。即对于$S1 = "你先走"，S2 = "你走先"$，2-gram模型表示为：$P(S1) = P("你")*P("先"|"你")*P("走"|"先")，P(S2) = P("你")*P("走"|"你")*P("先"|"走")$。由于$P("走"|"先")$要大于$P("先"|"走")$，则我们会得到$P(S1) > P(S2)$，因此2-gram模型相比1-gram模型准确率要高一些。

# %% [markdown]
# ## 编程实践部分

# %% [markdown]
# #### 1. 设计你自己的句子生成器

# %% [markdown]
# 如何生成句子是一个很经典的问题，从1940s开始，图灵提出机器智能的时候，就使用的是人类能不能流畅和计算机进行对话。和计算机对话的一个前提是，计算机能够生成语言。
#
# 计算机如何能生成语言是一个经典但是又很复杂的问题。 我们课程上为大家介绍的是一种基于规则（Rule Based）的生成方法。该方法虽然提出的时间早，但是现在依然在很多地方能够大显身手。值得说明的是，现在很多很实用的算法，都是很久之前提出的，例如，二分查找提出与1940s, Dijstra算法提出于1960s 等等。

# %% [markdown]
# 在著名的电视剧，电影《西部世界》中，这些机器人们语言生成的方法就是使用的SyntaxTree生成语言的方法。
#
# >
# >
#
# ![WstWorld](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1569578233461&di=4adfa7597fb380e7cc0e67190bbd7605&imgtype=0&src=http%3A%2F%2Fs1.sinaimg.cn%2Flarge%2F006eYYfyzy76cmpG3Yb1f)
#
# >
# >

# %% [markdown]
# 在这一部分，需要各位同学首先定义自己的语言。 大家可以先想一个应用场景，然后在这个场景下，定义语法。例如：
#
# 在西部世界里，一个”人类“的语言可以定义为：
# ```
# human = """
# human = 自己 寻找 活动
# 自己 = 我 | 俺 | 我们
# 寻找 = 看看 | 找找 | 想找点
# 活动 = 乐子 | 玩的
# """
# ```
#
# 一个“接待员”的语言可以定义为
# ```
# host = """
# host = 寒暄 报数 询问 业务相关 结尾
# 报数 = 我是 数字 号 ,
# 数字 = 单个数字 | 数字 单个数字
# 单个数字 = 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 | 9
# 寒暄 = 称谓 打招呼 | 打招呼
# 称谓 = 人称 ,
# 人称 = 先生 | 女士 | 小朋友
# 打招呼 = 你好 | 您好
# 询问 = 请问你要 | 您需要
# 业务相关 = 玩玩 具体业务
# 玩玩 = 耍一耍 | 玩一玩
# 具体业务 = 喝酒 | 打牌 | 打猎 | 赌博
# 结尾 = 吗？"""
#
# ```

# %% [markdown]
# 请定义你自己的语法:

# %% [markdown]
# 第一个语法：

# %%
# 定义在线问诊场景下接诊医生的语法
online_doctor_grammer = '''
doctor = 礼貌用语 询问 症状 时间 结尾
礼貌用语 = 你好, | 您好, | hello, | hi,
询问 = 请问您
症状 = 头疼 | 发烧 | 感冒 | 胃疼 | 痛风
时间 = 多长时间 | 多久 | 持续几天 | 存在几个月
结尾 = 了?
'''

# %% [markdown]
# > **评阅点**： 是否提出了和课程上区别较大的语法结构

# %% [markdown]
# 第二个语法：

# %%
# 定义一个店铺卖家的语法
online_service_grammer = '''
service = 称呼 欢迎用语 店铺 业务相关 产品 价格 结尾
称呼 = 亲, | 尊敬的顾客, | 亲亲,
欢迎用语 = 欢迎来到 | 欢迎光顾 | 欢迎光临
店铺 = xx专卖店, | xx旗舰店, | xx专营店,
业务相关 = 本店销售 | 本店主营
产品 = 笔记本电脑, | 键盘, | 口红, | 书包,
价格 = 价格实惠! | 只要999元! | 全场8折优惠!
结尾 = 您有什么需要吗？ | 很高兴为您服务!
'''

# %% [markdown]
# > **评阅点**：是否和上一个语法区别比较大

# %% [markdown]
# TODO: 然后，使用自己之前定义的generate函数，使用此函数生成句子。

# %%
def create_grammar(grammar_str, split='=', line_split='\n'):
    grammar = {}
    for line in grammar_str.split(line_split):
        if not line.strip(): continue
        exp, stmt = line.split(split)
        grammar[exp.strip()] = [s.split() for s in stmt.split('|')]
    return grammar

create_grammar(online_doctor_grammer)
# Out:
# {'doctor': [['礼貌用语', '询问', '症状', '时间', '结尾']],
#  '礼貌用语': [['你好,'], ['您好,'], ['hello,'], ['hi,']],
#  '询问': [['请问您']],
#  '症状': [['头疼'], ['发烧'], ['感冒'], ['胃疼'], ['痛风']],
#  '时间': [['多长时间'], ['多久'], ['持续几天'], ['存在几个月']],
#  '结尾': [['了?']]}

# %%
from random import choice
def generate(gram, target):
    if target not in gram: return target
    
    expaned = [generate(gram, t) for t in choice(gram[target])]
    return ''.join([e if e != '/n' else '\n' for e in expaned if e != 'null'])
generate(create_grammar(online_doctor_grammer), target='doctor')
# Out:
# '您好,请问您发烧多久了?'

# %% [markdown]
# TODO: 然后，定义一个函数，generate_n，将generate扩展，使其能够生成n个句子:

# %%
def generate_n(n, grammer_str, target):
    # you code here
    n_centences = []
    for i in range(n):
        n_centences.append(generate(create_grammar(grammer_str), target=target))
    return n_centences
print(generate_n(10, online_doctor_grammer, "doctor"))
print()
print(generate_n(10, online_service_grammer, "service"))
# Out:
# ['您好,请问您头疼多久了?', 'hello,请问您感冒多久了?', 'hi,请问您痛风多长时间了?', '您好,请问您头疼多久了?', 'hello,请问您痛风存在几个月了?', '您好,请问您发烧存在几个月了?', '你好,请问您发烧存在几个月了?', '你好,请问您头疼持续几天了?', 'hi,请问您胃疼存在几个月了?', 'hello,请问您感冒多久了?']
#
# ['亲亲,欢迎光顾xx专卖店,本地主营键盘,只要999元!您有什么需要吗？', '亲,欢迎光顾xx专营店,本店销售笔记本电脑,价格实惠!您有什么需要吗？', '亲,欢迎光顾xx专营店,本地主营笔记本电脑,价格实惠!您有什么需要吗？', '尊敬的顾客,欢迎来到xx旗舰店,本地主营书包,价格实惠!您有什么需要吗？', '亲亲,欢迎来到xx旗舰店,本地主营口红,价格实惠!您有什么需要吗？', '亲,欢迎来到xx专卖店,本地主营书包,全场8折优惠!很高兴为您服务!', '尊敬的顾客,欢迎光临xx专卖店,本地主营键盘,只要999元!您有什么需要吗？', '亲,欢迎光临xx专卖店,本店销售口红,只要999元!很高兴为您服务!', '亲,欢迎来到xx旗舰店,本地主营键盘,只要999元!您有什么需要吗？', '尊敬的顾客,欢迎光临xx专卖店,本店销售口红,只要999元!您有什么需要吗？']

# %% [markdown]
# > **评阅点**; 运行代码，观察是否能够生成多个句子

# %% [markdown]
# #### 2. 使用新数据源完成语言模型的训练

# %% [markdown]
# 按照我们上文中定义的`prob_2`函数，我们更换一个文本数据源，获得新的Language Model:
#
# 1. 下载文本数据集（你可以在以下数据集中任选一个，也可以两个都使用）
#     + 可选数据集1，保险行业问询对话集： https://github.com/Computing-Intelligence/insuranceqa-corpus-zh/raw/release/corpus/pool/train.txt.gz
#     + 可选数据集2：豆瓣评论数据集：https://github.com/Computing-Intelligence/datasource/raw/master/movie_comments.csv
# 2. 修改代码，获得新的**2-gram**语言模型
#     + 进行文本清洗，获得所有的纯文本
#     + 将这些文本进行切词
#     + 送入之前定义的语言模型中，判断文本的合理程度

# %%
import pandas as pd
import re

original_data = pd.read_csv('./data/sqlResult_1558435.csv', encoding='gb18030')
articles = original_data['content'].tolist()

# %%
# 去除标点符号、英文字符、数字
def clean(article):
    clean_article = ''.join(re.findall('\w+', str(article)))  # 去除标点符号
    pattern = re.compile('[A-Za-z\d]+')
    clean_article = pattern.sub('', str(clean_article))   # 去除英文字符和数字
    return clean_article

# 将清洗后的文本保存到文件中
def save(articles):
    with open('./data/article_9k.txt', 'w', encoding='utf-8') as f:
        for a in articles:
            f.write(a + '\n')

clean_articles = [clean(article) for article in articles]
save(clean_articles)

# %%
clean_articles[0]
# Out:
# '此外自本周月日起除小米手机等款机型外其余机型已暂停更新发布含开发版体验版内测稳定版暂不受影响以确保工程师可以集中全部精力进行系统优化工作有人猜测这也是将精力主要用到的研发之中去年月发布距今已有一年有余也是时候更新换代了当然关于的确切信息我们还是等待官方消息'

# %%
import jieba

# 分词处理
def cut_text():
    words_list = []
    with open('./data/article_9k.txt', 'r') as f:
        count = 0
        for line in f:
            words = list(jieba.cut(line.strip('\n')))
            words_list += words
           
    return words_list
    
        
words_list = cut_text()

# %%
words_list[:10]
# Out:
# ['此外', '自', '本周', '月', '日', '起', '除', '小米', '手机', '等款']

# %%
from collections import Counter

words_count = Counter(words_list)
words_count.most_common(20)
# Out:
# [('的', 703712),
#  ('在', 263462),
#  ('新华社', 142464),
#  ('和', 133722),
#  ('了', 121940),
#  ('月', 121169),
#  ('日', 111766),
#  ('是', 105273),
#  ('外代', 82425),
#  ('中', 73659),
#  ('中国', 71128),
#  ('年月日', 62312),
#  ('记者', 62142),
#  ('二线', 61998),
#  ('将', 61414),
#  ('与', 58294),
#  ('等', 57647),
#  ('年', 56539),
#  ('为', 56112),
#  ('照片', 52272)]

# %%
words_count['记者']
# Out:
# 62142

# %%
TOKENS_2GRAM = [''.join(words_list[i:i+2]) for i in range(len(words_list)-1)]

# %%
TOKENS_2GRAM
# Out:
# ['此外自',
#  '自本周',
#  '本周月',
#  '月日',
#  '日起',
#  '起除',
#  '除小米',
#  '小米手机',
#  '手机等款',
#  '等款机型',
#  '机型外',
#  '外其余',
#  '其余机型',
#  '机型已',
#  '已暂停',
#  '暂停更新',
#  '更新发布',
#  '发布含',
#  '含开发',
#  '开发版',
#  '版体验版',
#  '体验版内测',
#  '内测稳定版',
#  '稳定版暂不受',
#  '暂不受影响',
#  '影响以',
#  '以确保',
#  '确保工程师',
#  '工程师可以',
#  '可以集中',
#  '集中全部',
#  '全部精力',
#  '精力进行',
#  '进行系统优化',
#  '系统优化工作',
#  '工作有人',
#  '有人猜测',
#  '猜测这',
#  '这也',
#  '也是',
#  '是将',
#  '将精力',
#  '精力主要',
#  '主要用到',
#  '用到的',
#  '的研发',
#  '研发之中',
#  '之中去年',
#  '去年月',
#  '月发布',
#  '发布距今已有',
#  '距今已有一年',
#  '一年有余',
#  '有余也',
#  '也是',
#  '是时候',
#  '时候更新换代',
#  '更新换代了',
#  '了当然',
#  '当然关于',
#  '关于的',
#  '的确切',
#  '确切信息',
#  '信息我们',
#  '我们还是',
#  '还是等待',
#  '等待官方消息',
#  '官方消息骁龙',
#  '骁龙作为',
#  '作为唯一',
#  '唯一通过',
#  '通过桌面',
#  '桌面平台',
#  '平台认证',
#  '认证的',
#  '的处理器',
#  '处理器高通',
#  '高通强调',
#  '强调不会',
#  '不会因为',
#  '因为只',
#  '只考虑',
#  '考虑性能',
#  '性能而',
#  '而去',
#  '去屏蔽掉',
#  '屏蔽掉小',
#  '小核心',
#  '核心相反',
#  '相反他们',
#  '他们正',
#  '正联手',
#  '联手微软',
# ...

# %%
words_count2 = Counter(TOKENS_2GRAM)
words_count2.most_common(20)
# Out:
# [('月日', 75436),
#  ('外代二线', 60469),
#  ('新华社照片', 50401),
#  ('新华社记者', 30865),
#  ('日在', 25293),
#  ('年月日外代', 20851),
#  ('照片外代', 20777),
#  ('外代年月日', 20763),
#  ('比赛中', 20576),
#  ('月日电', 18307),
#  ('一带一路', 18299),
#  ('摄新华社', 16905),
#  ('当日在', 16376),
#  ('完新华社', 13893),
#  ('年月日体育', 12313),
#  ('日电记者', 11606),
#  ('二线足球', 11039),
#  ('在比赛', 9794),
#  ('举行的', 9547),
#  ('也是', 7122)]

# %%
words_list_len = len(words_list)
unique_words_len = len(words_count)
unique_bigram_len = len(words_count2)

# 计算词独立出现的概率，采用拉普拉斯平滑
def prob_1(word):
    return (words_count[word] + 1) / (words_list_len + unique_words_len)

# 计算条件概率，采用拉普拉斯平滑
def prob_2(word1, word2):
    return (words_count2[word1+word2] + 1) / (words_count[word1] + unique_bigram_len)

# 构建2-gram语言模型
def bigram_model(sentence):
    words = list(jieba.cut(sentence))
    probility = prob_1(words[0])
    for index in range(len(words)-1):
        probility *= prob_2(words[index], words[index+1])
    return probility
        

sent1 = "我爱你"
sent2 = "我你爱"
sent3 = "今天天气真好"
sent4 = "今天真天气好"
sent5 = "你先走"
sent6 = "你走先"
print(bigram_model(sent1))
print(bigram_model(sent2))
print(bigram_model(sent3))
print(bigram_model(sent4))
print(bigram_model(sent5))
print(bigram_model(sent6))
# Out:
# 5.9607783295715594e-06
# 1.2585314454141385e-14
# 6.751764045254859e-19
# 6.959695538300923e-24
# 1.2520998402585423e-15
# 3.909475699071306e-16

# %% [markdown]
# > **评阅点** 1. 是否使用了新的数据集； 2. csv(txt)数据是否正确解析

# %% [markdown]
# #### 3. 获得最优质的的语言

# %% [markdown]
# 当我们能够生成随机的语言并且能判断之后，我们就可以生成更加合理的语言了。请定义 generate_best 函数，该函数输入一个语法 + 语言模型，能够生成**n**个句子，并能选择一个最合理的句子:

# %% [markdown]
# 提示，要实现这个函数，你需要Python的sorted函数

# %%
sorted([1, 3, 5, 2])
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# 这个函数接受一个参数key，这个参数接受一个函数作为输入，例如

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[0])
# Out:
# [(1, 4), (2, 5), (4, 4), (5, 0)]

# %% [markdown]
# 能够让list按照第0个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1])
# Out:
# [(5, 0), (1, 4), (4, 4), (2, 5)]

# %% [markdown]
# 能够让list按照第1个元素进行排序.

# %%
sorted([(2, 5), (1, 4), (5, 0), (4, 4)], key=lambda x: x[1], reverse=True)
# Out:
# [(2, 5), (1, 4), (4, 4), (5, 0)]

# %% [markdown]
# 能够让list按照第1个元素进行排序, 但是是递减的顺序。

# %% [markdown]
# >

# %%
# 为了让语言模型测试效果更明显，生成一些不通顺的语法
online_service_grammer_test = '''
service = 称呼 欢迎用语 店铺 业务相关 产品 价格 结尾
称呼 = 亲, | 尊敬的顾客, | 亲亲,
欢迎用语 = 欢迎来到 | 欢迎光顾 | 欢迎光临 | 不通顺测试
店铺 = xx专卖店, | xx旗舰店, | xx专营店,
业务相关 = 本店销售 | 本地主营
产品 = 笔记本电脑, | 键盘, | 口红, | 书包, | 不通顺测试,
价格 = 价格实惠! | 只要999元! | 全场8折优惠!
结尾 = 您有什么需要吗？ | 很高兴为您服务!
'''

def generate_best(n, grammer, target, lang_model): # you code here
    n_centences = generate_n(n, grammer, target)
    return sorted(n_centences, key=lambda x: lang_model(x), reverse=True)

print(generate_best(10, online_doctor_grammer, "doctor", bigram_model))
print()
print(generate_best(10, online_service_grammer, "service", bigram_model))
print()
print(generate_best(20, online_service_grammer_test, "service", bigram_model))
# Out:
# ['你好,请问您感冒多久了?', 'hello,请问您感冒多久了?', 'hi,请问您头疼多长时间了?', '你好,请问您发烧持续几天了?', '您好,请问您感冒持续几天了?', '您好,请问您发烧持续几天了?', 'hello,请问您头疼持续几天了?', 'hello,请问您胃疼多长时间了?', '你好,请问您发烧存在几个月了?', '你好,请问您发烧存在几个月了?']
#
# ['亲亲,欢迎光临xx旗舰店,本店销售书包,只要999元!很高兴为您服务!', '亲,欢迎光顾xx专营店,本店主营键盘,价格实惠!很高兴为您服务!', '亲,欢迎光顾xx旗舰店,本店销售口红,只要999元!很高兴为您服务!', '亲亲,欢迎来到xx专营店,本店销售口红,全场8折优惠!很高兴为您服务!', '亲,欢迎光顾xx专营店,本店主营书包,全场8折优惠!很高兴为您服务!', '亲亲,欢迎光顾xx旗舰店,本店销售口红,只要999元!您有什么需要吗？', '亲亲,欢迎来到xx专营店,本店销售笔记本电脑,全场8折优惠!您有什么需要吗？', '亲,欢迎光顾xx专卖店,本店主营键盘,只要999元!您有什么需要吗？', '亲亲,欢迎来到xx旗舰店,本店主营书包,只要999元!您有什么需要吗？', '亲亲,欢迎来到xx专卖店,本店主营笔记本电脑,全场8折优惠!您有什么需要吗？']
#
# ...

# %% [markdown]
# 好了，现在我们实现了自己的第一个AI模型，这个模型能够生成比较接近于人类的语言。

# %% [markdown]
# > **评阅点**： 是否使用 lambda 语法进行排序

# %% [markdown]
# Q: 这个模型有什么问题？ 你准备如何提升？

# %% [markdown]
# - **稀疏性：**因为n-gram模型只能对文本中出现的单词或者单词组进行建模，当新的文本中出现意义相近但是没有在训练文本中出现的单词或者单词组的时候，传统离散模型无法正确计算这些训练样本中未出现的单词的应有概率，他们都会被赋予0概率预测值，即使我通过平滑技术也会得到非常小的概率。这是非常不符合语言规律的事情。
# - **泛化能力差：**对于n-gram模型来说，公式中马尔可夫假设太强。人在对文字进行处理的时候，是能够将很长一段上下文纳入考虑，但是n-gram的离散模型只考虑待预测单词前面的n-1个单词，这个马尔可夫假设与实际情况并不相符，使得公式中两个概率近似的要求其实并不能满足。
# - **计算复杂度：**当我们将更多单词组合挑出来之后才能更精准地预测特定单词组出现的概率，但是这种组合的量是非常大的。假设我们的词库有一万个独立单词，对于一个包含4个单词的词组模式，潜在的单词组合多达10的20次方。这使得突破一定的预测精度非常困难。
#
# **提升方法：**加大数据量、将2-gram改造成3-gram，但是都不能本质上解决上面的问题，传统语言模型的上述几个内在缺陷使得人们开始把目光转向神经网络模型，期望深度学习技术能够自动化地学习代表语法和语义的特征，解决稀疏性问题，并提高泛化能力。这里主要介绍两类神经网络模型：前馈神经网络模型（FFLM）和循环神经网络模型（RNNLM）。前者主要设计来解决稀疏性问题，而后者主要设计来解决泛化能力，尤其是对长上下文信息的处理。在实际工作中，基于循环神经网络及其变种的模型已经实现了非常好的效果。

# %% [markdown]
# >**评阅点**: 是否提出了比较实际的问题，例如OOV问题，例如数据量，例如变成 3-gram问题。

# %% [markdown]
# ##### 以下内容为可选部分，对于绝大多数同学，能完成以上的项目已经很优秀了，下边的内容如果你还有精力可以试试，但不是必须的。

# %% [markdown]
# #### 4. (Optional) 完成基于Pattern Match的语句问答
# > 另外一份作业文件里有个optional，有兴趣的同学可以挑战一下

# %% [markdown]
# 各位同学，我们已经完成了自己的第一个AI模型，大家对人工智能可能已经有了一些感觉，人工智能的核心就是，我们如何设计一个模型、程序，在外部的输入变化的时候，我们的程序不变，依然能够解决问题。人工智能是一个很大的领域，目前大家所熟知的深度学习只是其中一小部分，之后也肯定会有更多的方法提出来，但是大家知道人工智能的目标，就知道了之后进步的方向。

# %% [markdown]
# 然后，希望大家对AI不要有恐惧感，这个并不难，大家加油！

# %% [markdown]
# >

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1561828422005&di=48d19c16afb6acc9180183a6116088ac&imgtype=0&src=http%3A%2F%2Fb-ssl.duitang.com%2Fuploads%2Fitem%2F201807%2F28%2F20180728150843_BECNF.thumb.224_0.jpeg)
